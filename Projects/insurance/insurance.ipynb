# %%
import pandas as pd

# %%
df=pd.read_csv('insurance.csv')

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dropna(inplace=True)

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
df['sex'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
cat_columns = df.select_dtypes(include='object').columns

for col in cat_columns:
    unique_vals = df[col].unique()
    mapping_dict = {}
    i=1
    for val in unique_vals:
        mapping_dict[val]=i
        i+=1
    df[col] = df[col].map(mapping_dict)

# %%
df.dtypes
# Out:
# age           int64
# sex           int64
# bmi         float64
# children      int64
# smoker        int64
# region        int64
# charges     float64
# dtype: object

# %%
df
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    1  27.900         0       1       1  16884.92400
# 1      18    2  33.770         1       2       2   1725.55230
# 2      28    2  33.000         3       2       2   4449.46200
# 3      33    2  22.705         0       2       3  21984.47061
# 4      32    2  28.880         0       2       3   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    2  30.970         3       2       3  10600.54830
# 1334   18    1  31.920         0       2       4   2205.98080
# 1335   18    1  36.850         0       2       2   1629.83350
# 1336   21    1  25.800         0       2       1   2007.94500
# 1337   61    1  29.070         0       1       3  29141.36030
#
# [1337 rows x 7 columns]

# %%
df.to_csv("clean_insurance.csv")

# %%
x=df.drop('charges',axis=1)
y=df[['charges']]

# %%
x
# Out:
#       age  sex     bmi  children  smoker  region
# 0      19    1  27.900         0       1       1
# 1      18    2  33.770         1       2       2
# 2      28    2  33.000         3       2       2
# 3      33    2  22.705         0       2       3
# 4      32    2  28.880         0       2       3
# ...   ...  ...     ...       ...     ...     ...
# 1333   50    2  30.970         3       2       3
# 1334   18    1  31.920         0       2       4
# 1335   18    1  36.850         0       2       2
# 1336   21    1  25.800         0       2       1
# 1337   61    1  29.070         0       1       3
#
# [1337 rows x 6 columns]

# %%
y
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1337 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x, y, random_state=42, test_size=0.2)

# %%
x_train
# Out:
#       age  sex     bmi  children  smoker  region
# 1114   23    2  24.510         0       2       4
# 968    21    2  25.745         2       2       4
# 599    52    1  37.525         2       2       3
# 170    63    2  41.470         0       2       2
# 275    47    1  26.600         2       2       4
# ...   ...  ...     ...       ...     ...     ...
# 1096   51    1  34.960         2       1       4
# 1131   27    2  45.900         2       2       1
# 1295   20    2  22.000         1       2       1
# 861    38    1  28.000         3       2       1
# 1127   35    1  35.860         2       2       2
#
# [1069 rows x 6 columns]

# %%
x_test
# Out:
#       age  sex     bmi  children  smoker  region
# 900    49    2  22.515         0       2       4
# 1064   29    1  25.600         4       2       1
# 1256   51    1  36.385         3       2       3
# 298    31    2  34.390         3       1       3
# 237    31    2  38.390         2       2       2
# ...   ...  ...     ...       ...     ...     ...
# 534    64    2  40.480         0       2       2
# 542    63    1  36.300         0       2       2
# 760    22    1  34.580         2       2       4
# 1284   61    2  36.300         1       1       1
# 1285   47    1  24.320         0       2       4
#
# [268 rows x 6 columns]

# %%
x_test.shape, y_test.shape, x_train.shape, y_train.shape
# Out:
# ((268, 6), (268, 1), (1069, 6), (1069, 1))

# %%
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
rfr =RandomForestRegressor()
rfr.fit(x_train, y_train)
# Out:
# c:\Users\disha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1363: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor()

# %%
rfr.score(x_test, y_test)
# Out:
# 0.8840691062538851

# %%
rfr.score(x_train, y_train)
# Out:
# 0.9751188065440478

# %%
rfr.predict(x_test)
# Out:
# array([ 9917.213513 ,  6490.7324528, 11888.7824731, 43318.1318628,
#         7051.7790959,  9865.8515959, 38894.6646662,  2608.7223486,
#         8835.0094119, 11223.9125061, 14752.4412053, 23431.768867 ,
#        43791.1808448, 15394.0824809,  7133.2363754,  8744.6043049,
#         6724.3550773, 39418.015175 ,  5152.931089 ,  4764.892465 ,
#         3974.3245502, 21099.6638759, 10043.4021511, 20185.5989645,
#        39536.2231565, 16488.8909008, 42884.94968  , 45932.471043 ,
#        10868.8422867, 14414.9911493,  4617.9213359,  9420.3986377,
#         3291.9817247, 14940.0329693, 47289.4093336,  9724.09277  ,
#         8986.0846612,  5793.2459737, 23240.9694454,  8833.6615785,
#         4180.868712 , 21377.3326233, 41612.9576326,  9603.902918 ,
#         9079.3533429,  3365.7015313,  4378.0460215,  7766.8761666,
#         5732.289452 , 10263.3703783,  5143.9796611,  9835.8428584,
#        22639.1018135,  3887.7147955,  7716.8467114,  8725.2001432,
#        11734.3297901,  7305.3744724, 41633.0222453,  7459.0841974,
#        11197.5533829,  5301.356266 , 18843.4767243,  1755.6809505,
#        13631.22787  , 13142.570664 ,  7206.7466051, 22464.970822 ,
#        16880.048864 , 18506.8410197, 13534.9485649, 14649.019939 ,
#         7596.2664438,  7089.4528352, 11945.5659613,  3504.5090751,
#        14735.359439 ,  5578.1075087, 11684.314925 , 12804.458283 ,
#         9897.3530867, 17942.5808157, 13850.8771913, 10416.0715966,
#        28613.2457105, 14206.7662633,  3820.0419099,  2759.093174 ,
#         6942.7181095,  3788.7813368, 14955.2962524, 17961.0299909,
#         6079.8053373,  8579.5162072,  1762.231981 , 43775.3331285,
#        12172.3354969,  9540.9490851,  3772.2023156,  9737.2599585,
#        13741.1550826, 16809.1741923, 25064.5323706, 15630.9819641,
#        40203.7002492,  1627.826905 , 40572.0100408, 19512.2539261,
#        12781.3895878,  6435.6559904,  7154.647322 , 12721.7920496,
#         7013.4662748,  6832.365503 ,  2350.0937428,  2152.7421225,
